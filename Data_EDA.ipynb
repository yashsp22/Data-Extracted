# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv('data1.csv')
df.head()
# Out:
#                                           Questions  \
# 0  What is a Credit Card and how credit card works?
# 1                     How to use credit card wisely
# 2                       How does a credit card work
# 3          how many types of credit card are there?
# 4                   How to apply for a credit card?
#
#                                              Answers  Category
# 0  A credit card is a specially designed payment ...  Gen Info
# 1  Credit cards are very easy to use, you can use...  Gen Info
# 2  With a credit card, you can borrow money from ...  Gen Info
# 3  To serve the demands of people, credit card co...  Gen Info
# 4  Nowadays if you have the eligibility, it is ve...  Gen Info

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3465 entries, 0 to 3464
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Questions  3465 non-null   object
#  1   Answers    3465 non-null   object
#  2   Category   3465 non-null   object
# dtypes: object(3)
# memory usage: 81.3+ KB

# %%
df['Category'].value_counts()
# Out:
# Gen Info                       766
# Bills,Statement & Limit        569
# Queries                        553
# Rewards & Cashback             270
# Score & Report                 258
# Interest & APR                 228
# Bank & Customer Care           214
# Fraud,Loss,Theft & Disputes    191
# Charges & Fees                 149
# online                         104
# PIN                             92
# contactless                     43
# Debt                            28
# Name: Category, dtype: int64

# %%
plt.figure(figsize=(30,13))
sns.countplot(x='Category', data=df)
plt.show()
